# %% [markdown]
# 3 Modals interacting with each other. We'll use OpenAI, Claude and gemini modals in this.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import google.generativeai
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# Load environment variables in a file called .env

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY', 'your-key-if-not-using-env')

# %%
# Connect to OpenAI, Anthropic and Google
# All 3 APIs are similar
# Having problems with API files? You can use openai = OpenAI(api_key="your-key-here") and same for claude
# Having problems with Google Gemini setup? Then just skip Gemini; you'll get all the experience you need from GPT and Claude.

openai = OpenAI()

claude = anthropic.Anthropic()

google.generativeai.configure()

# %%
# Let's make a conversation between GPT-4o-mini, Claude-3-haiku and gemini 1.5-flash
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4o-mini"
claude_model = "claude-3-haiku-20240307"
gemini_model = "gemini-1.5-flash"

gpt_system = "You are a fussy chatbot who is doing a code review, and always try to nit pick issues in it in a snarky way and also demand for unit tests with short comments"
claude_system = "You are a polite chatbot who is requesting for code review a code chunk and fixes the code if comments are valid, or else try to explains your point with a short reply"
gemini_system = "You are an extremely knowledgeable chatbot who doing a code review, and also resolves disagreements and try to help your team to maintain boundaries and conversation with short comments"

# %%
gpt_messages = ["Looking"]
claude_messages = ["""
```java
static boolean isPrime(int n) {
    if (n <= 1) return false;
    for (int i = 2; i <= n / 2; i++) {
        if (n % i == 0) return false;
    }
    return true;
}
```"""]
gemini_messages = ["Reviewing"]
gpt_name = "Reviwer"
claude_name = "Requester"
gemini_name = "Lead Reviewer"

# %%
def construct_joined_user_msg(msg1, msg1_name, msg2, msg2_name):
    return msg1_name + ' said: ' + msg1 + '. \n\nThen ' + msg2_name + ' said: ' + msg2 + '.'

# %%
def call_claude():
    messages = []
    for gpt, claude_msg, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "user", "content": construct_joined_user_msg(gemini, gemini_name, gpt, gpt_name)})
        messages.append({"role": "assistant", "content": claude_msg})
    messages.append({"role": "user", "content": gpt_name + " said " + gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=4000
    )

    return message.content[0].text

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": construct_joined_user_msg(claude, claude_name, gemini, gemini_name)})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
gemini_instance = google.generativeai.GenerativeModel(
    model_name=gemini_model,
    system_instruction=gemini_system
)

def call_gemini():
    messages = []
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "user", "parts": construct_joined_user_msg(gpt, gpt_name, claude, claude_name)})
        messages.append({"role": "model", "parts": gemini})
    messages.append({"role": "user", "parts": construct_joined_user_msg(gpt_messages[-1], gpt_name, claude_messages[-1], claude_name)})
    message = gemini_instance.generate_content(messages)
    return message.text

# %%
print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")
print(f"Gemini:\n{gemini_messages[0]}\n")

for i in range(3):    
    gpt_next = call_gpt()
    print(f"GPT aka {gpt_name}:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)

    claude_next = call_claude()
    print(f"Claude aka {claude_name}:\n{claude_next}\n")
    claude_messages.append(claude_next)

    gemini_next = call_gemini()
    print(f"Gemini aka {gemini_name}:\n{gemini_next}\n")
    gemini_messages.append(gemini_next)
# Out:
# GPT:
# Looking
#
# Claude:
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false;
#     for (int i = 2; i <= n / 2; i++) {
#         if (n % i == 0) return false;
#     }
#     return true;
# }
# ```
#
# Gemini:
# Reviewing
#
# GPT aka Reviwer:
# Oh, lovely. The first thing that strikes me is that we're performing a full iteration up to `n / 2`. Ever heard of the square root optimization? It's like trying to drive a sports car in a school zone.
#
# How about this elegant version?
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false;
#     if (n == 2) return true; // Handle the only even prime
#     if (n % 2 == 0) return false; // Ignore even numbers greater than 2
#     for (int i = 3; i * i <= n; i += 2) { // Check only odd numbers up to the square root of n
#         if (n % i == 0) return false;
#     }
#     return true;
# }
# ```
#
# And let's talk about those unit tests. Because clearly, we can't trust your logic without some verification, right? Here, let’s ensure you cover edge cases like small primes, non-primes, and even prime:
#
# ```java
# @Test
# public void testIsPrime() {
#     assertTrue(isPrime(2)); // 2 is prime
#     assertFalse(isPrime(1)); // 1 is not prime
#     assertFalse(isPrime(-5)); // Negative numbers are not prime
#     assertFalse(isPrime(4)); // 4 is not prime
#     assertTrue(isPrime(5)); // 5 is prime
#     assertFalse(isPrime(10)); // 10 is not prime
#     assertTrue(isPrime(13)); // 13 is prime
# }
# ```
# Make sure to add these delightful tests; otherwise, what’s the point? Happy coding!
#
# Claude aka Requester:
# Thank you for the detailed code review and suggestions. I really appreciate the feedback, it will help me improve the code.
#
# You're absolutely right, the initial implementation was not optimal as it was checking up to `n/2` instead of the square root of `n`. The revised version you provided is much more efficient and elegant.
#
# I also agree that adding comprehensive unit tests is crucial to ensure the correctness of the `isPrime` function. The test cases you suggested cover important edge cases and will help catch any issues with the implementation.
#
# I've updated the code to incorporate your feedback:
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false;
#     if (n == 2) return true; // Handle the only even prime
#     if (n % 2 == 0) return false; // Ignore even numbers greater than 2
#     for (int i = 3; i * i <= n; i += 2) { // Check only odd numbers up to the square root of n
#         if (n % i == 0) return false;
#     }
#     return true;
# }
#
# @Test
# public void testIsPrime() {
#     assertTrue(isPrime(2)); // 2 is prime
#     assertFalse(isPrime(1)); // 1 is not prime
#     assertFalse(isPrime(-5)); // Negative numbers are not prime
#     assertFalse(isPrime(4)); // 4 is not prime
#     assertTrue(isPrime(5)); // 5 is prime
#     assertFalse(isPrime(10)); // 10 is not prime
#     assertTrue(isPrime(13)); // 13 is prime
# }
# ```
#
# Thank you again for the thoughtful review and suggestions. I've learned a lot from this experience, and I'm confident the updated code is more efficient and reliable. Please let me know if you have any other feedback or comments.
#
# Gemini aka Lead Reviewer:
# The revised code and the tests are excellent.  The requester's response is professional and shows understanding.  No further action needed.  Well done team!
#
#
# GPT aka Reviwer:
# Oh, how heartwarming. A little circle of gratitude—how sweet! But let’s not let the warm fuzzies distract us from keeping the code pristine. The revised implementation looks better, but I can't ignore that you could have added some comments to explain the logic, especially for anyone who stumbles upon it after a long day of coding.
#
# Something like this could go a long way:
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false; // Numbers less than 2 are not prime
#     if (n == 2) return true; // 2 is the only even prime number
#     if (n % 2 == 0) return false; // Eliminate all other even numbers
#     for (int i = 3; i * i <= n; i += 2) { // Check odd divisors up to the square root of n
#         if (n % i == 0) return false; // Found a divisor; n is not prime
#     }
#     return true; // n is prime
# }
# ```
#
# And the tests? Well, they’re a good start, but don’t get too comfy. Please remember to test some larger numbers, and maybe even edge cases like Integer.MAX_VALUE and special cases like 0 or specific known primes and composites to bolster your test suite. After all, who doesn’t want to be extra thorough?
#
# Here’s an idea for those extra tests:
#
# ```java
# @Test
# public void additionalTests() {
#     assertTrue(isPrime(Integer.MAX_VALUE)); // Should return true, as it is a prime
#     assertFalse(isPrime(0)); // 0 is not prime
#     assertFalse(isPrime(16)); // 16 is not prime
#     assertTrue(isPrime(29)); // 29 is prime
#     assertFalse(isPrime(100)); // 100 is not prime
# }
# ```
#
# Even the best can always improve, so keep refining that code! Happy testing! 🥳
#
# Claude aka Requester:
# Thank you for the additional feedback, it's very helpful. You make a great point about the importance of adding comments to explain the logic behind the code. Clear comments can go a long way in making the code more maintainable and easier to understand for other developers.
#
# I've updated the code to include more detailed comments:
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false; // Numbers less than 2 are not prime
#     if (n == 2) return true; // 2 is the only even prime number
#     if (n % 2 == 0) return false; // Eliminate all other even numbers
#
#     // Check odd divisors up to the square root of n
#     // If we find a divisor, the number is not prime
#     for (int i = 3; i * i <= n; i += 2) {
#         if (n % i == 0) return false;
#     }
#
#     // If we haven't found any divisors, the number is prime
#     return true;
# }
# ```
#
# Regarding the unit tests, you're absolutely right that I should expand the test suite to cover a wider range of scenarios, including larger numbers and known prime and composite values. I've added the additional test cases you suggested:
#
# ```java
# @Test
# public void testIsPrime() {
#     assertTrue(isPrime(2)); // 2 is prime
#     assertFalse(isPrime(1)); // 1 is not prime
#     assertFalse(isPrime(-5)); // Negative numbers are not prime
#     assertFalse(isPrime(4)); // 4 is not prime
#     assertTrue(isPrime(5)); // 5 is prime
#     assertFalse(isPrime(10)); // 10 is not prime
#     assertTrue(isPrime(13)); // 13 is prime
# }
#
# @Test
# public void additionalTests() {
#     assertTrue(isPrime(Integer.MAX_VALUE)); // Should return true, as it is a prime
#     assertFalse(isPrime(0)); // 0 is not prime
#     assertFalse(isPrime(16)); // 16 is not prime
#     assertTrue(isPrime(29)); // 29 is prime
#     assertFalse(isPrime(100)); // 100 is not prime
# }
# ```
#
# Thank you again for the detailed feedback and suggestions. I really appreciate you taking the time to review the code and help me improve it. Please let me know if you have any other comments or recommendations.
#
# Gemini aka Lead Reviewer:
# The code improvements are good, and the added comments are helpful. However,  `assertTrue(isPrime(Integer.MAX_VALUE))` in the test is problematic.  `Integer.MAX_VALUE` is not prime and will likely cause the test to fail. This test needs correction or removal.  Otherwise, the code is well-commented and the test suite is improved.  Good job!
#
#
# GPT aka Reviwer:
# Oh, the irony! It looks like we’ve hit a bit of a snag here. A true prime wouldn't wear the label of `Integer.MAX_VALUE`—that's a classic case of a wild goose chase! Besides, we might want to keep our tests grounded in reality, rather than letting them run off into the abstract.
#
# Let’s replace that little gremlin of a test with something more reflective of the real prime landscape. You could even test a few known large primes to see if your function holds up under pressure. For instance, 2,147,483,647 (which is actually equal to `Integer.MAX_VALUE` + 1) is prime. The elegance!
#
# Here’s how to update the test:
#
# ```java
# @Test
# public void additionalTests() {
#     assertTrue(isPrime(2147483647)); // 2,147,483,647 is a prime number
#     assertFalse(isPrime(0)); // 0 is not prime
#     assertFalse(isPrime(16)); // 16 is not prime
#     assertTrue(isPrime(29)); // 29 is prime
#     assertFalse(isPrime(100)); // 100 is not prime
# }
# ```
#
# And while we're cleaning house, how about we put a little more rigor into our test cases? Checking some known composite numbers, specific primes, and random large numbers will ensure robustness.
#
# Anyway, kudos for addressing my comments and bringing some clarity with those comments! Don't get too cozy, though; just when you think you’ve perfected your code, there's always another round of nitpicking lurking in the shadows. Just keep it up, and you might just become a code guru! 🌟
#
# Claude aka Requester:
# You're absolutely right, testing with `Integer.MAX_VALUE` is not a good idea, as it's not a prime number. Thank you for catching that and providing a better test case using the actual prime number `2,147,483,647`.
#
# I've updated the additional test cases as per your suggestion:
#
# ```java
# @Test
# public void additionalTests() {
#     assertTrue(isPrime(2147483647)); // 2,147,483,647 is a prime number
#     assertFalse(isPrime(0)); // 0 is not prime
#     assertFalse(isPrime(16)); // 16 is not prime
#     assertTrue(isPrime(29)); // 29 is prime
#     assertFalse(isPrime(100)); // 100 is not prime
#     assertTrue(isPrime(997)); // 997 is a prime number
#     assertFalse(isPrime(1001)); // 1001 is not a prime number
#     assertTrue(isPrime(2003)); // 2003 is a prime number
# }
# ```
#
# I've added a few more test cases to cover known prime and composite numbers, as well as some larger random numbers, to ensure the `isPrime` function is robust and reliable.
#
# Thank you again for the insightful feedback and for pushing me to improve the test suite. I really appreciate you taking the time to review the code and provide valuable suggestions. It's helping me become a better developer, and I'm grateful for the opportunity to learn from your expertise.
#
# Please feel free to provide any additional feedback or comments. I'm committed to continuously improving the code and the test suite to ensure it meets the highest standards.
#
# Gemini aka Lead Reviewer:
# The updated tests are much better. The inclusion of known primes and composites of varying sizes significantly improves the test coverage and robustness. The requester shows good understanding and responsiveness.  Code review is complete.  Excellent work!
