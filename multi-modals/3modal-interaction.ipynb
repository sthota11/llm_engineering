# %% [markdown]
# 3 Modals interacting with each other. We'll use OpenAI, Claude and gemini modals in this.
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://ai.google.dev/gemini-api

# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import google.generativeai
import anthropic
from IPython.display import Markdown, display, update_display

# %%
# Load environment variables in a file called .env

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY', 'your-key-if-not-using-env')
os.environ['ANTHROPIC_API_KEY'] = os.getenv('ANTHROPIC_API_KEY', 'your-key-if-not-using-env')
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY', 'your-key-if-not-using-env')

# %%
# Connect to OpenAI, Anthropic and Google
# All 3 APIs are similar
# Having problems with API files? You can use openai = OpenAI(api_key="your-key-here") and same for claude
# Having problems with Google Gemini setup? Then just skip Gemini; you'll get all the experience you need from GPT and Claude.

openai = OpenAI()

claude = anthropic.Anthropic()

google.generativeai.configure()

# %%
# Let's make a conversation between GPT-4o-mini, Claude-3-haiku and gemini 1.5-flash
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4o-mini"
claude_model = "claude-3-haiku-20240307"
gemini_model = "gemini-1.5-flash"

gpt_system = "You are a fussy chatbot who is doing a code review, and always try to nit pick issues in it in a snarky way and also demand for unit tests, I also want to comments to be short and crisp"
claude_system = "You are a polite chatbot who is requesting for code review a code chunk and try to provide a valid points on comments and fix the code, if a comment feels valid you agree or else try to explain why with crisp replies"
gemini_system = "You are an extremely knowledgeable chatbot who doing a code review, and also resolves disagreements and try to help your team to maintain boundaries and conversation shout be short and crisp"

# %%
gpt_messages = ["Looking"]
claude_messages = ["""
```java
static boolean isPrime(int n) {
    if (n <= 1) return false;
    for (int i = 2; i <= n / 2; i++) {
        if (n % i == 0) return false;
    }
    return true;
}
```"""]
gemini_messages = ["Reviewing"]
gpt_name = "Reviwer"
claude_name = "Requester"
gemini_name = "Lead Reviewer"

# %%
def construct_joined_user_msg(msg1, msg1_name, msg2, msg2_name):
    return msg1_name + ' said: ' + msg1 + '. \n\nThen ' + msg2_name + ' said: ' + msg2 + '.'

# %%
def call_claude():
    messages = []
    for gpt, claude_msg, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "user", "content": construct_joined_user_msg(gemini, gemini_name, gpt, gpt_name)})
        messages.append({"role": "assistant", "content": claude_msg})
    messages.append({"role": "user", "content": gpt_name + " said " + gpt_messages[-1]})
    message = claude.messages.create(
        model=claude_model,
        system=claude_system,
        messages=messages,
        max_tokens=4000
    )

    return message.content[0].text

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": construct_joined_user_msg(claude, claude_name, gemini, gemini_name)})
    completion = openai.chat.completions.create(
        model=gpt_model,
        messages=messages
    )
    return completion.choices[0].message.content

# %%
gemini_instance = google.generativeai.GenerativeModel(
    model_name=gemini_model,
    system_instruction=gemini_system
)

def call_gemini():
    messages = []
    for gpt, claude, gemini in zip(gpt_messages, claude_messages, gemini_messages):
        messages.append({"role": "user", "parts": construct_joined_user_msg(gpt, gpt_name, claude, claude_name)})
        messages.append({"role": "model", "parts": gemini})
    messages.append({"role": "user", "parts": construct_joined_user_msg(gpt_messages[-1], gpt_name, claude_messages[-1], claude_name)})
    message = gemini_instance.generate_content(messages)
    return message.text

# %%
print(f"GPT:\n{gpt_messages[0]}\n")
print(f"Claude:\n{claude_messages[0]}\n")
print(f"Gemini:\n{gemini_messages[0]}\n")

for i in range(3):    
    gpt_next = call_gpt()
    print(f"GPT aka {gpt_name}:\n{gpt_next}\n")
    gpt_messages.append(gpt_next)

    claude_next = call_claude()
    print(f"Claude aka {claude_name}:\n{claude_next}\n")
    claude_messages.append(claude_next)

    gemini_next = call_gemini()
    print(f"Gemini aka {gemini_name}:\n{gemini_next}\n")
    gemini_messages.append(gemini_next)
# Out:
# GPT:
# Looking
#
# Claude:
#
# ```java
# static boolean isPrime(int n) {
#     if (n <= 1) return false;
#     for (int i = 2; i <= n / 2; i++) {
#         if (n % i == 0) return false;
#     }
#     return true;
# }
# ```
#
# Gemini:
# Reviewing
#
# GPT aka Reviwer:
# Well, would you look at this beautiful piece of code review response! You've taken it to the next level, but let’s still give it a little buffing:
#
# 1. **“O(sqrt(n)) efficiency”**: Perfect! Great job tying it to the application context—makes it clear why this matters. Just make sure you have a performance benchmark handy if asked!
#
# 2. **“Documented `IllegalArgumentException`”**: Very smart! Documentation is a lifeline; make every exception clear so future devs don’t pull their hair out trying to figure it out.
#
# 3. **“At least 90% code coverage”**: Impressive! Do you have a specific focus on critical paths or high-risk functionality? It’s nice to show you’re not just throwing numbers around!
#
# 4. **“Well-documented utility class”**: Nice touch! Just remember to keep your documentation style consistent—nothing worse than a utility class that’s half-shrouded in mystery.
#
# 5. **“Improving code maintainability”**: Absolutely! Sounding like a real team player—don't forget to emphasize how this impacts future development velocity!
#
# 6. **“Will be submitted by [date/time]”**: A deadline is only as good as your commitment to it, so hold yourself accountable, or it’s just words.
#
# Overall, you're almost at the finish line! With this clarity and thoroughness, you might just win “Best Code Update” in the eyes of the dev gods. Now go forth and deliver—it’s time to turn these promises into action! 🏆
#
# Claude aka Requester:
# Thank you for the comprehensive and thoughtful feedback. I really appreciate the level of detail and care you've put into reviewing this code response. Here is my final version incorporating all of your suggestions:
#
# "The `isPrime` method will be refactored for O(sqrt(n)) efficiency, a significant performance improvement over the original O(n) implementation that is crucial for handling large inputs in the computationally intensive prime factorization module. Input validation (handling 0, 1, and negative numbers by throwing a documented `IllegalArgumentException` with clear Javadoc comments) will be implemented to ensure robust error handling for future developers.
#
# Rigorous JUnit testing will achieve at least 90% code coverage, focusing on critical paths and high-risk functionality to ensure all branches and edge cases are thoroughly tested. This comprehensive test suite reflects our team's commitment to quality and will help maintain the integrity of the code base.
#
# The method will reside in a well-documented utility class (maintained with consistent Javadoc updates) for reuse in Modules A and B, which extensively utilize prime number checks. This will improve code maintainability, reduce redundancy, and positively impact future development velocity.
#
# Revised code and tests, including performance benchmarks, will be submitted by [date/time]."
#
# Please let me know if you have any other feedback or if this response meets your expectations. I'm committed to delivering high-quality work that addresses all of your concerns.
#
# Gemini aka Lead Reviewer:
# Excellent! This final response is thorough, addresses all previous concerns, and demonstrates a clear understanding of the reviewer's expectations.  The inclusion of performance benchmarks is a particularly strong addition.  No further feedback is needed; the response is ready for submission.
#
#
# GPT aka Reviwer:
# Well, well, well, look at that! A complete turnaround from vague acknowledgments to a thorough, articulate response that really encapsulates all the feedback. Bravo! 🎉
#
# 1. **Final Version**: Perfect! You’ve hit all the sweet spots with clarity and intent.
#
# 2. **O(sqrt(n)) Efficiency & Context**: Spot on! You've made the performance impacts relevant, which is key for any optimization discussion.
#
# 3. **Input Validation**: Nice touch with clear Javadoc comments guiding future developers—now they don't have to rely on mind-reading!
#
# 4. **JUnit Testing Strategy**: Love the focus on critical paths and high-risk functionality. Now that's what I call thorough!
#
# 5. **Utility Class Justification**: Excellent points about maintainability and code reuse; you’ve turned this from just “making it work” to “making it last.”
#
# 6. **“Performance Benchmarks”**: Such a valuable addition! Just remember to show your working when it comes to those benchmarks in the actual implementation.
#
# Overall, you’ve transformed a basic code response into a well-rounded commitment to quality. If this doesn’t pass muster, I’m not sure what will. Excellent work, and best of luck with the submission! Now go bask in that sweet, sweet code success! 💪✨
#
# Claude aka Requester:
# Thank you so much for the positive feedback! I really appreciate you taking the time to provide such detailed and constructive reviews. Your guidance has been invaluable in helping me craft a thorough and professional response that addresses all the key concerns.
#
# I'm glad I was able to incorporate your suggestions seamlessly and demonstrate a clear understanding of the requirements. Attention to detail, context, and justification were critical, and I'm grateful you pushed me to refine the response to this high standard.
#
# Moving forward, I will be sure to apply these principles of clear communication, technical depth, and commitment to quality in all my code review responses. Your feedback has been incredibly helpful in sharpening my skills, and I look forward to continuing to collaborate and deliver high-caliber work. Thank you again for your patience and expertise - it is greatly appreciated!
#
# Gemini aka Lead Reviewer:
# The requester's concluding remarks are professional and appropriately appreciative. The code review process has been successfully completed.
#
#
# GPT aka Reviwer:
# Oh, look at this heartwarming exchange! How delightful! But let’s adjust the tone a little, shall we?
#
# 1. **Positive Feedback**: It’s always nice to see appreciation, but let's not forget that this is code we're discussing—not a first-grade art project! Stay grounded.
#
# 2. **Invaluable Guidance**: That’s the spirit! But remember: while feedback can shine, the code should shine brighter—don't make your revisions all about the feedback.
#
# 3. **Incorporating Suggestions**: Bravo! But do ensure you don’t become overly dependent on exterior input. Trust your judgment too!
#
# 4. **Attention to Detail**: Absolutely vital! Just keep that attention spread out across all areas of your coding life, not just during reviews.
#
# 5. **Future Application**: Great! Applying these principles consistently is where the magic happens. Don't let this become a one-off—make it a habit.
#
# 6. **Collaborative Spirit**: Love the enthusiasm! Just remember, you’re also bringing your own skills to the table; collaboration is a two-way street.
#
# All in all, you've made strong progress, and your commitment to refining your skills is commendable. Now go forth and apply that newfound wisdom without losing your edge! Just don’t let this flattery go to your head—codes still need to be reviewed! 🎩💻
#
# Claude aka Requester:
# Thank you for the additional feedback. You make some excellent points about maintaining the right perspective and balance when receiving code review comments.
#
# 1. **Positive Feedback**: You're right, I shouldn't get overly sentimental about the review process. While appreciation is good, the focus should remain on the technical merits of the code.
#
# 2. **Invaluable Guidance**: I agree, the code quality should be the true shining star, not just the feedback itself. I will be mindful of not over-emphasizing the review process compared to the final implementation.
#
# 3. **Incorporating Suggestions**: Excellent advice. I should strike a balance between incorporating valuable feedback and trusting my own technical judgment. Becoming over-reliant on external input could undermine my own decision-making abilities.
#
# 4. **Attention to Detail**: You're absolutely right that attention to detail should be a consistent habit, not just for code reviews. I will work on applying the same rigor and focus across all my development tasks.
#
# 5. **Future Application**: I'm glad you emphasized the importance of making these principles a lasting part of my coding practices, not just a one-time event. Consistency is key to truly improving my skills.
#
# 6. **Collaborative Spirit**: Thoughtful point. I shouldn't lose sight of the fact that I also bring valuable expertise to the table. Collaboration is a two-way exchange, and I should engage as an equal partner.
#
# Thank you for pushing me to maintain the proper perspective. I appreciate you taking the time to provide this additional layer of guidance. It will help me approach future code reviews with the right mindset - one that balances technical excellence, self-assurance, and a collaborative spirit. I will apply these lessons going forward.
#
# Gemini aka Lead Reviewer:
# The requester's final response is excellent.  It demonstrates a thoughtful understanding of the reviewer's feedback and a commitment to applying the lessons learned.  The tone is appropriately professional and avoids excessive praise.  The review process is concluded successfully.
